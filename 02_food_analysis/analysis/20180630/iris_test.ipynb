# %%
import seaborn as sns

# %%
sns.set(style="ticks", color_codes=True)

# %%
from matplotlib import rc, font_manager
from matplotlib import pyplot as plt
font_location = "C:/Windows/Fonts/NanumSquareR.ttf"
font_manager.FontProperties(fname=font_location)
rc('font', family="NanumSquare")

# %%
iris = sns.load_dataset("iris")

# %%
sns.pairplot(iris)

# %%
import pandas as pd

# %%
food = pd.read_excel('OPENDATA_FOOD_1.xls')

# %%
food.head()
# Out:
#    번호        식품군              식품이름  1회제공량 (g)  열량 (kcal) 탄수화물 (g) 단백질 (g)  \
# 0   1  곡류 및 그 제품       고량미,고량미, 알곡        100      349.0     67.8    10.1
# 1   2  곡류 및 그 제품    과자,스넥과자, 유아용과자         30      129.9    20.13    3.54
# 2   3  곡류 및 그 제품   귀리 가공(기타), 오트밀         100      382.0     64.9    13.2
# 3   4  곡류 및 그 제품   귀리 가공(기타), 오트밀         100      348.0     64.9    13.2
# 4   5  곡류 및 그 제품  귀리(겉귀리), 도정곡, 생것        100      373.0     73.5    11.4
#
#   지방 (g)  당류 (g) 나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# 0    3.7     0.0      NaN          0        0.0         0.0  2001
# 1   3.96     0.0     57.6          0        0.0         0.0  2006
# 2    8.2     0.0        4          0        0.0         0.0  2011
# 3    8.2     NaN        4        NaN        NaN         0.0  2017
# 4    3.7     0.0        2          0        0.0         0.0  2011

# %%
food.shape
# Out:
# (4903, 14)

# %%
a = food.drop_duplicates(['식품이름'], keep='last')
a.shape
# Out:
# (2605, 14)

# %%
a.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal) 탄수화물 (g) 단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.8    10.1
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자         30      129.9    20.13    3.54
# 3   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.9    13.2
# 5   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.5    11.4
# 7   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.4    14.3
#
#   지방 (g)  당류 (g) 나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# 0    3.7     0.0      NaN          0        0.0         0.0  2001
# 1   3.96     0.0     57.6          0        0.0         0.0  2006
# 3    8.2     NaN        4        NaN        NaN         0.0  2017
# 5    3.7     NaN        2        NaN        NaN         0.0  2017
# 7    3.8     NaN        3        NaN        NaN         0.0  2017

# %% [markdown]
# - 중복을 제거한 데이터의 인덱스를 재배열 해야한다.

# %%
a = a.reset_index()

# %%
a.head()
# Out:
#    index  번호        식품군               식품이름  1회제공량 (g)  열량 (kcal) 탄수화물 (g)  \
# 0      0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.8
# 1      1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자         30      129.9    20.13
# 2      3   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.9
# 3      5   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.5
# 4      7   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.4
#
#   단백질 (g) 지방 (g)  당류 (g) 나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# 0    10.1    3.7     0.0      NaN          0        0.0         0.0  2001
# 1    3.54   3.96     0.0     57.6          0        0.0         0.0  2006
# 2    13.2    8.2     NaN        4        NaN        NaN         0.0  2017
# 3    11.4    3.7     NaN        2        NaN        NaN         0.0  2017
# 4    14.3    3.8     NaN        3        NaN        NaN         0.0  2017

# %%
del a['index']

# %%
a.head(10)
# Out:
#    번호        식품군                  식품이름  1회제공량 (g)  열량 (kcal) 탄수화물 (g) 단백질 (g)  \
# 0   1  곡류 및 그 제품           고량미,고량미, 알곡        100      349.0     67.8    10.1
# 1   2  곡류 및 그 제품        과자,스넥과자, 유아용과자         30      129.9    20.13    3.54
# 2   4  곡류 및 그 제품       귀리 가공(기타), 오트밀         100      348.0     64.9    13.2
# 3   6  곡류 및 그 제품      귀리(겉귀리), 도정곡, 생것        100      332.0     73.5    11.4
# 4   8  곡류 및 그 제품     귀리(쌀귀리),  도정곡, 생것        100      334.0     70.4    14.3
# 5  10  곡류 및 그 제품           기장, 도정곡, 생것        100      360.0     74.6    11.2
# 6  11  곡류 및 그 제품             냄비우동, 냉동         100      206.0     43.9       6
# 7  13  곡류 및 그 제품      녹두 가공(면류), 녹두국수         100      356.0     87.5     0.2
# 8  14  곡류 및 그 제품      대두 가공(과자류), 엿강정          30      135.3    11.73   11.31
# 9  16  곡류 및 그 제품  도토리 가공(면류), 국수, 마른것         100      307.0     72.2    12.4
#
#   지방 (g)  당류 (g) 나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# ...

# %%
a.to_csv('delete_duplicated.csv')

# %%
a.to_excel('delete_duplicated.xlsx')

# %%
a = a.fillna(0.0)

# %%
a.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal) 탄수화물 (g) 단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.8    10.1
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자         30      129.9    20.13    3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.9    13.2
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.5    11.4
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.4    14.3
#
#   지방 (g)  당류 (g) 나트륨 (mg)  콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# 0    3.7     0.0        0         0.0        0.0         0.0  2001
# 1   3.96     0.0     57.6         0.0        0.0         0.0  2006
# 2    8.2     0.0        4         0.0        0.0         0.0  2017
# 3    3.7     0.0        2         0.0        0.0         0.0  2017
# 4    3.8     0.0        3         0.0        0.0         0.0  2017

# %%
amount = a['1회제공량 (g)']
kcal = a['열량 (kcal)']
cardo = a['탄수화물 (g)']
protain = a['단백질 (g)']
fatt = a['지방 (g)']

# %%
def set_amount(i_list, a, t):
    i_list.append((100.0 * t) / a)

# %%
r_kcal = 100.0 * kcal / amount

# %%
cardo = cardo.tolist()

# %%
for i in cardo:
    print(type(i))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
cardo = [int(i) for i in cardo]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-266-a385759bd73a> in <module>()
# ----> 1 cardo = [int(i) for i in cardo]
#
# <ipython-input-266-a385759bd73a> in <listcomp>(.0)
# ----> 1 cardo = [int(i) for i in cardo]
#
# ValueError: invalid literal for int() with base 10: 'trace'

# %%
cardo
# Out:
# [67.8,
#  20.13,
#  64.9,
#  73.5,
#  70.4,
#  74.6,
#  43.9,
#  87.5,
#  11.73,
#  72.2,
#  14.67,
#  10.17,
#  18.5,
#  78.69,
#  27.79,
#  23.82,
#  71.36,
#  74.41,
#  22.65,
#  61.14,
#  25.73,
#  73.66,
#  67.84,
#  78.5,
#  32.16,
#  78.2,
#  89.96,
#  21.36,
#  80.7,
#  48.8,
#  47.8,
#  45.6,
#  45.2,
#  46.14,
#  53,
#  52.5,
#  41.2,
#  44.01,
#  43.6,
#  38.94,
#  55.6,
#  49.04,
#  45.23,
#  72.6,
#  86.8,
#  4.7,
#  33.2,
#  15.6,
#  83.7,
#  4.4,
#  37.3,
#  15.2,
#  75.8,
#  79.5,
#  75.31,
#  72.89,
#  73.9,
#  77.5,
#  75.52,
#  77.04,
#  76.64,
#  31.68,
#  71.5,
#  78.41,
#  75.9,
#  75.37,
#  70.86,
#  82.62,
#  60.34,
#  62.63,
#  64.98,
#  84,
#  82.8,
#  60.92,
#  27.52,
#  66.32,
#  65.73,
#  71.7,
#  32.9,
#  57.3,
#  38.1,
#  65.6,
#  70.2,
#  67.59,
#  67.97,
#  66.47,
#  71.38,
#  58.8,
#  64.23,
#  68.24,
#  43.2,
#  74,
#  24.87,
#  69.05,
#  77.1,
#  25.8,
#  74.86,
#  25.31,
#  76.64,
#  26.9,
#  33.09,
#  29.12,
#  67.1,
#  28.6,
#  55.7,
#  29.2,
# ...

# %%
r_cardo = (100.0 * cardo) / amount
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
# ...

# %%
a['1회제공량 (g)'] = 100
a['열량 (kcal)'] = r_kcal
a['탄수화물 (g)'] = r_cr
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal) 탄수화물 (g) 단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.8    10.1
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자        100      129.9    20.13    3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.9    13.2
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.5    11.4
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.4    14.3
#
#   지방 (g)  당류 (g) 나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# 0    3.7     0.0      NaN          0        0.0         0.0  2001
# 1   3.96     0.0     57.6          0        0.0         0.0  2006
# 2    8.2     NaN        4        NaN        NaN         0.0  2017
# 3    3.7     NaN        2        NaN        NaN         0.0  2017
# 4    3.8     NaN        3        NaN        NaN         0.0  2017

# %%
result_amount = []
kcal = []
cardo = []
protain = []
fatt = []

for i in range(len(a)):
    lis = a.loc[i]
    lis = pd.to_numeric(lis[3:])
    print(lis)
#     result_amount.append(100)
#     amount = lis[0]
#     tem = lis[1]
#     kcal.append((100.0 * tem) / amount)
# Out:
# 1회제공량 (g)      100.0
# 열량 (kcal)      349.0
# 탄수화물 (g)        67.8
# 단백질 (g)         10.1
# 지방 (g)           3.7
# 당류 (g)           0.0
# 나트륨 (mg)         NaN
# 콜레스테롤 (mg)       0.0
# 포화지방산 (g)        0.0
# 트랜스지방산 (g)       0.0
# 년도            2001.0
# Name: 0, dtype: float64
# 1회제공량 (g)       30.00
# 열량 (kcal)      129.90
# 탄수화물 (g)        20.13
# 단백질 (g)          3.54
# 지방 (g)           3.96
# 당류 (g)           0.00
# 나트륨 (mg)        57.60
# 콜레스테롤 (mg)       0.00
# 포화지방산 (g)        0.00
# 트랜스지방산 (g)       0.00
# 년도            2006.00
# Name: 1, dtype: float64
# 1회제공량 (g)      100.0
# 열량 (kcal)      348.0
# 탄수화물 (g)        64.9
# 단백질 (g)         13.2
# 지방 (g)           8.2
# 당류 (g)           NaN
# 나트륨 (mg)         4.0
# 콜레스테롤 (mg)       NaN
# 포화지방산 (g)        NaN
# 트랜스지방산 (g)       0.0
# 년도            2017.0
# Name: 2, dtype: float64
# 1회제공량 (g)      100.0
# 열량 (kcal)      332.0
# 탄수화물 (g)        73.5
# 단백질 (g)         11.4
# 지방 (g)           3.7
# 당류 (g)           NaN
# ...

# %%
lis = a.loc[0]

# %% [markdown]
# 원래 수치 : 제공량 = 원하는 수치 : 100g
#
#
# 원하는 수치 * 제공량 = 원래수치 * 100
#
# 100g일때의 원하는 수치 =  (원래 수치 * 100) / 제공량

# %%
type(lis)
# Out:
# pandas.core.series.Series

# %%
lis
# Out:
# 번호                      1
# 식품군             곡류 및 그 제품
# 식품이름          고량미,고량미, 알곡
# 1회제공량 (g)             100
# 열량 (kcal)             349
# 탄수화물 (g)             67.8
# 단백질 (g)              10.1
# 지방 (g)                3.7
# 당류 (g)                  0
# 나트륨 (mg)              NaN
# 콜레스테롤 (mg)              0
# 포화지방산 (g)               0
# 트랜스지방산 (g)              0
# 년도                   2001
# Name: 0, dtype: object

# %%
lis = pd.to_numeric(lis[3:])

# %%
lis
# Out:
# 1회제공량 (g)      100.0
# 열량 (kcal)      349.0
# 탄수화물 (g)        67.8
# 단백질 (g)         10.1
# 지방 (g)           3.7
# 당류 (g)           0.0
# 나트륨 (mg)         NaN
# 콜레스테롤 (mg)       0.0
# 포화지방산 (g)        0.0
# 트랜스지방산 (g)       0.0
# 년도            2001.0
# Name: 0, dtype: float64

# %%
amount = lis[0]
tem = lis[1]
print((100 * tem) / amount )
# Out:
# 349.0

# %%
type(lis[0])
# Out:
# numpy.float64
