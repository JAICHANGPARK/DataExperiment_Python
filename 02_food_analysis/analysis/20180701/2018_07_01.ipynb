# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform
path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %%
food = pd.read_excel('final_food_01.xlsx', encoding='utf-8')
food  = food.fillna(0.0)
food.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.80    10.10
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자        100      129.9     20.13     3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.90    13.20
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.50    11.40
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.40    14.30
#
#    지방 (g)  당류 (g)  나트륨 (mg)  콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도
# 0    3.70     0.0       0.0         0.0        0.0           0  2001
# 1    3.96     0.0      57.6         0.0        0.0           0  2006
# 2    8.20     0.0       4.0         0.0        0.0           0  2017
# 3    3.70     0.0       2.0         0.0        0.0           0  2017
# 4    3.80     0.0       3.0         0.0        0.0           0  2017

# %%
amount = food['1회제공량 (g)']
kcal = food['열량 (kcal)']
cardo = food['탄수화물 (g)']
protain = food['단백질 (g)']
fatt = food['지방 (g)']

# %%
step_01 = (cardo * 4) + (protain * 4) + (fatt * 9)

# %%
food['step_01'] = step_01

# %%
food.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.80    10.10
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자        100      129.9     20.13     3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.90    13.20
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.50    11.40
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.40    14.30
#
#    지방 (g)  당류 (g)  나트륨 (mg)  콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도  step_01
# 0    3.70     0.0       0.0         0.0        0.0           0  2001   344.90
# 1    3.96     0.0      57.6         0.0        0.0           0  2006   130.32
# 2    8.20     0.0       4.0         0.0        0.0           0  2017   386.20
# 3    3.70     0.0       2.0         0.0        0.0           0  2017   372.90
# 4    3.80     0.0       3.0         0.0        0.0           0  2017   373.00

# %%
diff = kcal - step_01

# %%
food['diff'] = diff

# %%
step_01_round = round(step_01 / kcal * 100 ,2)

# %%
food['step_01_round'] = step_01_round

# %%
food.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.80    10.10
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자        100      129.9     20.13     3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.90    13.20
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.50    11.40
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.40    14.30
#
#    지방 (g)  당류 (g)  나트륨 (mg)  콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도  step_01  \
# 0    3.70     0.0       0.0         0.0        0.0           0  2001   344.90
# 1    3.96     0.0      57.6         0.0        0.0           0  2006   130.32
# 2    8.20     0.0       4.0         0.0        0.0           0  2017   386.20
# 3    3.70     0.0       2.0         0.0        0.0           0  2017   372.90
# 4    3.80     0.0       3.0         0.0        0.0           0  2017   373.00
#
#     diff  step_01_round
# ...

# %%
food.to_excel('20180701_food_step01.xlsx')

# %%
food[0:100]
# Out:
#      번호        식품군                            식품이름  1회제공량 (g)  열량 (kcal)  \
# 0     1  곡류 및 그 제품                     고량미,고량미, 알곡        100      349.0
# 1     2  곡류 및 그 제품                  과자,스넥과자, 유아용과자        100      129.9
# 2     4  곡류 및 그 제품                 귀리 가공(기타), 오트밀         100      348.0
# 3     6  곡류 및 그 제품                귀리(겉귀리), 도정곡, 생것        100      332.0
# 4     8  곡류 및 그 제품               귀리(쌀귀리),  도정곡, 생것        100      334.0
# 5    10  곡류 및 그 제품                     기장, 도정곡, 생것        100      360.0
# 6    11  곡류 및 그 제품                       냄비우동, 냉동         100      206.0
# 7    13  곡류 및 그 제품                녹두 가공(면류), 녹두국수         100      356.0
# 8    14  곡류 및 그 제품                대두 가공(과자류), 엿강정         100      135.3
# 9    16  곡류 및 그 제품            도토리 가공(면류), 국수, 마른것         100      307.0
# 10   17  곡류 및 그 제품                들깨 가공(과자류), 엿강정         100      161.4
# 11   18  곡류 및 그 제품                땅콩 가공(과자류), 엿강정         100      173.4
# ...

# %% [markdown]
# ## 식품군 종류의 모든 수를 카운트 해본다.
# ### 식품군을 교환단위의 식품군으로 구분하는것이 중요

# %%
kind_count = food.groupby(food['식품군']).size()

# %% [markdown]
# 내림차순으로 정리한다.

# %%
kind_count = kind_count.sort_values(ascending = False)

# %%
kind_count.plot.barh()

# %%
food.groupby(food['식품군']).describe()
# Out:
#           1회제공량 (g)                                                  diff  \
#               count   mean  std    min    25%    50%    75%    max  count
# 식품군
# 감자 및 전분류       43.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   43.0
# 견과류            70.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   70.0
# 곡류 및 그 제품     292.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0  292.0
# 과실류           157.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0  157.0
# 기타             37.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   37.0
# 난류             19.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   19.0
# 당류 및 그 제품      58.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   58.0
# 두류 및 그 제품      46.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   46.0
# 버섯류            56.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   56.0
# 어패류           701.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0  701.0
# 우유 및 유제품       40.0  100.0  0.0  100.0  100.0  100.0  100.0  100.0   40.0
# ...

# %%
gokryu = food[0:335]

# %%
gokryu.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.80    10.10
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자        100      129.9     20.13     3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.90    13.20
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.50    11.40
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.40    14.30
#
#    지방 (g)  당류 (g)  나트륨 (mg)  콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도  step_01  \
# 0    3.70     0.0       0.0         0.0        0.0           0  2001   344.90
# 1    3.96     0.0      57.6         0.0        0.0           0  2006   130.32
# 2    8.20     0.0       4.0         0.0        0.0           0  2017   386.20
# 3    3.70     0.0       2.0         0.0        0.0           0  2017   372.90
# 4    3.80     0.0       3.0         0.0        0.0           0  2017   373.00
#
#     diff  step_01_round
# ...

# %%
gokryu_fatt = gokryu['지방 (g)']

# %%
step_02 = 100 - gokryu_fatt

# %%
gokryu_kcal = gokryu['열량 (kcal)']

# %%
k = gokryu_kcal - (gokryu_fatt * 9)

# %%
gokryu_carbo = gokryu['탄수화물 (g)']
gokryu_protain = gokryu['단백질 (g)']

l = gokryu_carbo + gokryu_protain

# %%
gokryu['k']= k
gokryu['l'] = l
# Out:
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
gokryu
# Out:
#       번호        식품군                             식품이름  1회제공량 (g)  열량 (kcal)  \
# 0      1  곡류 및 그 제품                      고량미,고량미, 알곡        100     349.00
# 1      2  곡류 및 그 제품                   과자,스넥과자, 유아용과자        100     129.90
# 2      4  곡류 및 그 제품                  귀리 가공(기타), 오트밀         100     348.00
# 3      6  곡류 및 그 제품                 귀리(겉귀리), 도정곡, 생것        100     332.00
# 4      8  곡류 및 그 제품                귀리(쌀귀리),  도정곡, 생것        100     334.00
# 5     10  곡류 및 그 제품                      기장, 도정곡, 생것        100     360.00
# 6     11  곡류 및 그 제품                        냄비우동, 냉동         100     206.00
# 7     13  곡류 및 그 제품                 녹두 가공(면류), 녹두국수         100     356.00
# 8     14  곡류 및 그 제품                 대두 가공(과자류), 엿강정         100     135.30
# 9     16  곡류 및 그 제품             도토리 가공(면류), 국수, 마른것         100     307.00
# 10    17  곡류 및 그 제품                 들깨 가공(과자류), 엿강정         100     161.40
# ...

# %%
tmp_exchg = l / 25

# %%
round_value = gokryu['step_01_round']

# %%
tmp_weight = round_value / tmp_exchg

# %%
gokryu['round_o'] = round(tmp_weight, 0)
# Out:
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
gokryu.head()
# Out:
#    번호        식품군               식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  \
# 0   1  곡류 및 그 제품        고량미,고량미, 알곡        100      349.0     67.80    10.10
# 1   2  곡류 및 그 제품     과자,스넥과자, 유아용과자        100      129.9     20.13     3.54
# 2   4  곡류 및 그 제품    귀리 가공(기타), 오트밀         100      348.0     64.90    13.20
# 3   6  곡류 및 그 제품   귀리(겉귀리), 도정곡, 생것        100      332.0     73.50    11.40
# 4   8  곡류 및 그 제품  귀리(쌀귀리),  도정곡, 생것        100      334.0     70.40    14.30
#
#    지방 (g)  당류 (g)  나트륨 (mg)  콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)    년도  step_01  \
# 0    3.70     0.0       0.0         0.0        0.0           0  2001   344.90
# 1    3.96     0.0      57.6         0.0        0.0           0  2006   130.32
# 2    8.20     0.0       4.0         0.0        0.0           0  2017   386.20
# 3    3.70     0.0       2.0         0.0        0.0           0  2017   372.90
# 4    3.80     0.0       3.0         0.0        0.0           0  2017   373.00
#
# ...

# %%
W = (gokryu_carbo * 4 ) + (gokryu_protain * 4 )

# %%
W = W / 100

# %%
last_weight = round_value / W

# %%
gokryu['last_weight'] = last_weight
# Out:
# c:\users\home613\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
gokryu.to_excel('second_step_food_20180701.xlsx')
