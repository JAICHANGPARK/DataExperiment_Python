# %%
import pandas as pd
import numpy as np

# %%
food01 = pd.read_excel('../data/OPENDATA_FOOD_1.xls')
food02 = pd.read_excel('../data/OPENDATA_FOOD_2.xls')
food03 = pd.read_excel('../data/OPENDATA_FOOD_3.xls')

# %%
food03.head(5)
# Out:
#    번호  식품군            식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  지방 (g)  \
# 0   1  과자류  츄파춥스 엑스엑스엘 트리오         10      11.00      2.70     0.00    0.00
# 1   2  과자류            오징어집         30      84.79     10.12     1.19    4.46
# 2   3  과자류             감자깡         30     150.00     22.00     2.00    6.00
# 3   4  과자류             감자깡         30     150.00     22.00     2.00    6.00
# 4   5  과자류      후라이드치킨 닭다리         30     155.45     18.55     1.64    8.18
#
#    당류 (g)  나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)
# 0    2.20      0.00          0       0.00        0.00
# 1    0.45     80.33       0.82       1.40        0.00
# 2    1.00    150.00          0       1.80        0.00
# 3    0.26    150.00          0       1.80        0.00
# 4    1.09    147.27          0       2.29        0.15

# %%
food03.dtypes
# Out:
# 번호              int64
# 식품군            object
# 식품이름           object
# 1회제공량 (g)       int64
# 열량 (kcal)     float64
# 탄수화물 (g)      float64
# 단백질 (g)       float64
# 지방 (g)        float64
# 당류 (g)        float64
# 나트륨 (mg)      float64
# 콜레스테롤 (mg)     object
# 포화지방산 (g)     float64
# 트랜스지방산 (g)    float64
# dtype: object

# %%
food03.<TAB>
# Out:
#   File "<ipython-input-19-1550344b845b>", line 1
#     food03.<TAB>
#            ^
# SyntaxError: invalid syntax

# %%
food03.index
# Out:
# RangeIndex(start=0, stop=25070, step=1)

# %%
food03.columns
# Out:
# Index(['번호', '식품군', '식품이름', '1회제공량 (g)', '열량 (kcal)', '탄수화물 (g)', '단백질 (g)',
#        '지방 (g)', '당류 (g)', '나트륨 (mg)', '콜레스테롤 (mg)', '포화지방산 (g)',
#        '트랜스지방산 (g)'],
#       dtype='object')

# %%
food03.loc[:,['열량 (kcal)','식품이름']]
# Out:
#        열량 (kcal)                                   식품이름
# 0          11.00                         츄파춥스 엑스엑스엘 트리오
# 1          84.79                                   오징어집
# 2         150.00                                    감자깡
# 3         150.00                                    감자깡
# 4         155.45                             후라이드치킨 닭다리
# 5          84.79                             후라이드치킨 닭다리
# 6         152.73                             핫숯불바베큐 닭다리
# 7          83.31                             핫숯불바베큐 닭다리
# 8         513.60                  라면,봉지면, 너구리, 순한맛(㈜농심)
# 9         616.32                  라면,봉지면, 너구리, 순한맛(㈜농심)
# 10        513.60                 라면,봉지면, 너구리, 얼큰한맛(㈜농심)
# 11        616.32                 라면,봉지면, 너구리, 얼큰한맛(㈜농심)
# 12        526.80                       라면,봉지면, 신라면(㈜농심)
# 13        632.16                       라면,봉지면, 신라면(㈜농심)
# 14        506.40                    라면,봉지면, 안성탕면김치(㈜농심)
# 15        607.68                    라면,봉지면, 안성탕면김치(㈜농심)
# 16        528.00                    라면,봉지면, 칼슘안성탕면(㈜농심)
# 17        633.60                    라면,봉지면, 칼슘안성탕면(㈜농심)
# 18        372.00                    라면,용기면, 새우탕큰사발(㈜농심)
# 19        297.60                    라면,용기면, 새우탕큰사발(㈜농심)
# 20        376.80                    라면,용기면, 육개장사발면(㈜농심)
# 21        301.44                    라면,용기면, 육개장사발면(㈜농심)
# 22        367.20                  라면,용기면, 큰사발면, 김치(㈜농심)
# 23        293.76                  라면,용기면, 큰사발면, 김치(㈜농심)
# 24        353.60                   라면,용기면, 튀김우동큰사발(㈜농심)
# 25        282.88                   라면,용기면, 튀김우동큰사발(㈜농심)
# 26         46.36                                   별따먹자
# 27        150.00                               별따먹자콩고물맛
# 28        104.65                               별따먹자콩고물맛
# 29        155.00                                   조청유과
# ...          ...                                    ...
# 25040     278.00                          마카다미아 넛 아이스크림
# 25041     221.00                           하겐다즈 망고&라즈베리
# 25042     100.00                                 체리마루 바
# 25043     100.00                             체리마루 600ml
# 25044     100.00                             체리마루 600ml
# 25045     116.67                                 체리마루 컵
# 25046     142.86                                 체리마루 바
# 25047     105.00                                 체리마루 컵
# 25048     181.82                              젤라또 슈(초코)
# 25049      70.00                           젤라또 슈(딸기요거트)
# 25050     212.12                           젤라또 슈(딸기요거트)
# 25051      60.00                              젤라또 슈(초코)
# 25052      15.00  백설햄 계란을 입혀 부쳐 먹으면 정말 맛있는 소시지(씨제이제일제당)
# 25053      22.50                     빅핫바 붉닭구이맛(소디프비앤에프)
# 25054      65.01                     빅후랑크 청양고추(소디프비앤에프)
# 25055      75.00                     빅핫바 붉닭구이맛(소디프비앤에프)
# 25056      75.00                     더건강한미니비엔나(씨제이제일제당)
# 25057      22.50                     더건강한미니비엔나(씨제이제일제당)
# 25058      50.01  백설햄 계란을 입혀 부쳐 먹으면 정말 맛있는 소시지(씨제이제일제당)
# 25059      19.50                     빅후랑크 청양고추(소디프비앤에프)
# 25060      86.98                                  옛날설렁탕
# 25061      66.00                                 옛날도가니탕
# 25062      36.24                                  옛날설렁탕
# 25063     158.40                                 옛날도가니탕
# 25064     137.09                                 옛날꼬리곰탕
# 25065     114.62                                  옛날갈비탕
# 25066      47.76                                  옛날갈비탕
# 25067      37.68                                 옛날사골곰탕
# 25068      57.12                                 옛날꼬리곰탕
# 25069      90.43                                 옛날사골곰탕
#
# [25070 rows x 2 columns]

# %%
import pymysql

# %%
conn = pymysql.connect(host='183.111.138.191', user='itsmejefffrey', password='kangwon2018',
                       db='itsmejefffrey', charset='utf8')

# %%
curs = conn.cursor(pymysql.cursors.DictCursor)
# SQL문 실행
sql = "select * from db_food_01"

curs.execute(sql)
rows = curs.fetchall()
print(rows)     # 전체 rows
conn.close()
# Out:
# [{'1회제공량 (g)': 210, '식품이름': b'\xeb\xb3\xb6\xec\x9d\x8c\xeb\xb0\xa5,\xed\x96\x84\xeb\xb3\xb6\xec\x9d\x8c\xeb\xb0\xa5', '콜레스테롤 (mg)': b'0', '번호': 1, '나트륨 (mg)': None, '지방 (g)': b'39.69', '트랜스지방산 (g)': 0.0, '열량 (kcal)': 518.7, '당류 (g)': 0.0, '포화지방산 (g)': 0.0, '탄수화물 (g)': b'0', '식품군': b'\xea\xb3\xa1\xeb\xa5\x98 \xeb\xb0\x8f \xea\xb7\xb8 \xec\xa0\x9c\xed\x92\x88', '단백질 (g)': b'7.14'}, {'1회제공량 (g)': 100, '식품이름': b'\xea\xb7\x80\xeb\xa6\xac(\xea\xb2\x89\xea\xb7\x80\xeb\xa6\xac), \xeb\x8f\x84\xec\xa0\x95\xea\xb3\xa1, \xec\x83\x9d\xea\xb2\x83', '콜레스테롤 (mg)': b'0', '번호': 2, '나트륨 (mg)': b'2', '지방 (g)': b'3.7', '트랜스지방산 (g)': 0.0, '열량 (kcal)': 373.0, '당류 (g)': 0.0, '포화지방산 (g)': 0.0, '탄수화물 (g)': b'73.5', '식품군': b'\xea\xb3\xa1\xeb\xa5\x98 \xeb\xb0\x8f \xea\xb7\xb8 \xec\xa0\x9c\xed\x92\x88', '단백질 (g)': b
# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://itsmejefffrey:"+"kangwon2018"+"@183.111.138.191:3306/itsmejefffrey?charset=utf8", encoding='utf-8')

# %%
conn = engine.connect()

# %%
conn

# %%
food01.to_sql(name='db_food_01', con=engine, if_exists='append',  index=False )
food02.to_sql(name='db_food_02', con=engine, if_exists='append',  index=False )
food03.to_sql(name='db_food_03', con=engine, if_exists='append',  index=False )

# %%
conn.close()

# %%
import pymysql

# %%
db = pymysql.connect(host='183.111.138.191', 
                     user='itsmejefffrey', 
                     password='kangwon2018',
                     db='itsmejefffrey', 
                     charset='utf8')

# %%
SQL = "SELECT * FROM db_food_03"
df = pd.read_sql(SQL,db)

# %%
df
# Out:
#           번호                                                식품군  \
# 0          1            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 1          2            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 2          3            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 3          4            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 4          5            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 5          6            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 6          7            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 7          8            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 8          9            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 9         10            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 10        11            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 11        12            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 12        13            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 13        14            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 14        15            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 15        16            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 16        17            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 17        18            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 18        19            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 19        20            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 20        21            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 21        22            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 22        23            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 23        24            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 24        25            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 25        26            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 26        27            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 27        28            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 28        29            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# 29        30            b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'
# ...      ...                                                ...
# 25040  25041  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25041  25042  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25042  25043  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25043  25044  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25044  25045  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25045  25046  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25046  25047  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25047  25048  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25048  25049  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25049  25050  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25050  25051  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25051  25052  b'\xec\x95\x84\xec\x9d\xb4\xec\x8a\xa4\xed\x81...
# 25052  25053  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25053  25054  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25054  25055  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25055  25056  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25056  25057  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25057  25058  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25058  25059  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25059  25060  b'\xec\x86\x8c\xec\x8b\x9c\xec\xa7\x80\xeb\xa5...
# 25060  25061  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25061  25062  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25062  25063  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25063  25064  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25064  25065  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25065  25066  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25066  25067  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25067  25068  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25068  25069  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
# 25069  25070  b'\xec\x8b\x9d\xec\x9c\xa1 \xec\xb6\x94\xec\xb...
#
#                                                     식품이름  1회제공량 (g)  \
# 0      b'\xec\xb8\x84\xed\x8c\x8c\xec\xb6\xa5\xec\x8a...         10
# 1      b'\xec\x98\xa4\xec\xa7\x95\xec\x96\xb4\xec\xa7...         30
# 2                b'\xea\xb0\x90\xec\x9e\x90\xea\xb9\xa1'         30
# 3                b'\xea\xb0\x90\xec\x9e\x90\xea\xb9\xa1'         30
# 4      b'\xed\x9b\x84\xeb\x9d\xbc\xec\x9d\xb4\xeb\x93...         30
# 5      b'\xed\x9b\x84\xeb\x9d\xbc\xec\x9d\xb4\xeb\x93...         30
# 6      b'\xed\x95\xab\xec\x88\xaf\xeb\xb6\x88\xeb\xb0...         30
# 7      b'\xed\x95\xab\xec\x88\xaf\xeb\xb6\x88\xeb\xb0...         30
# 8      b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 9      b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 10     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 11     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 12     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 13     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 14     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 15     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 16     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 17     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xeb\xb4\x89\xec\xa...        120
# 18     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 19     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 20     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 21     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 22     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 23     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 24     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 25     b'\xeb\x9d\xbc\xeb\xa9\xb4,\xec\x9a\xa9\xea\xb...         80
# 26     b'\xeb\xb3\x84\xeb\x94\xb0\xeb\xa8\xb9\xec\x9e...         30
# 27     b'\xeb\xb3\x84\xeb\x94\xb0\xeb\xa8\xb9\xec\x9e...         30
# 28     b'\xeb\xb3\x84\xeb\x94\xb0\xeb\xa8\xb9\xec\x9e...         30
# 29     b'\xec\xa1\xb0\xec\xb2\xad\xec\x9c\xa0\xea\xb3...         30
# ...                                                  ...        ...
# 25040  b'\xeb\xa7\x88\xec\xb9\xb4\xeb\x8b\xa4\xeb\xaf...        100
# 25041  b'\xed\x95\x98\xea\xb2\x90\xeb\x8b\xa4\xec\xa6...        100
# 25042  b'\xec\xb2\xb4\xeb\xa6\xac\xeb\xa7\x88\xeb\xa3...        100
# 25043  b'\xec\xb2\xb4\xeb\xa6\xac\xeb\xa7\x88\xeb\xa3...        100
# 25044  b'\xec\xb2\xb4\xeb\xa6\xac\xeb\xa7\x88\xeb\xa3...        100
# 25045  b'\xec\xb2\xb4\xeb\xa6\xac\xeb\xa7\x88\xeb\xa3...        100
# 25046  b'\xec\xb2\xb4\xeb\xa6\xac\xeb\xa7\x88\xeb\xa3...        100
# 25047  b'\xec\xb2\xb4\xeb\xa6\xac\xeb\xa7\x88\xeb\xa3...        100
# 25048  b'\xec\xa0\xa4\xeb\x9d\xbc\xeb\x98\x90 \xec\x8...        100
# 25049  b'\xec\xa0\xa4\xeb\x9d\xbc\xeb\x98\x90 \xec\x8...        100
# 25050  b'\xec\xa0\xa4\xeb\x9d\xbc\xeb\x98\x90 \xec\x8...        100
# 25051  b'\xec\xa0\xa4\xeb\x9d\xbc\xeb\x98\x90 \xec\x8...        100
# 25052  b'\xeb\xb0\xb1\xec\x84\xa4\xed\x96\x84 \xea\xb...         30
# 25053  b'\xeb\xb9\x85\xed\x95\xab\xeb\xb0\x94 \xeb\xb...         30
# 25054  b'\xeb\xb9\x85\xed\x9b\x84\xeb\x9e\x91\xed\x81...         30
# 25055  b'\xeb\xb9\x85\xed\x95\xab\xeb\xb0\x94 \xeb\xb...         30
# 25056  b'\xeb\x8d\x94\xea\xb1\xb4\xea\xb0\x95\xed\x95...         30
# 25057  b'\xeb\x8d\x94\xea\xb1\xb4\xea\xb0\x95\xed\x95...         30
# 25058  b'\xeb\xb0\xb1\xec\x84\xa4\xed\x96\x84 \xea\xb...         30
# 25059  b'\xeb\xb9\x85\xed\x9b\x84\xeb\x9e\x91\xed\x81...         30
# 25060  b'\xec\x98\x9b\xeb\x82\xa0\xec\x84\xa4\xeb\xa0...        240
# 25061  b'\xec\x98\x9b\xeb\x82\xa0\xeb\x8f\x84\xea\xb0...        240
# 25062  b'\xec\x98\x9b\xeb\x82\xa0\xec\x84\xa4\xeb\xa0...        240
# 25063  b'\xec\x98\x9b\xeb\x82\xa0\xeb\x8f\x84\xea\xb0...        240
# 25064  b'\xec\x98\x9b\xeb\x82\xa0\xea\xbc\xac\xeb\xa6...        240
# 25065  b'\xec\x98\x9b\xeb\x82\xa0\xea\xb0\x88\xeb\xb9...        240
# 25066  b'\xec\x98\x9b\xeb\x82\xa0\xea\xb0\x88\xeb\xb9...        240
# 25067  b'\xec\x98\x9b\xeb\x82\xa0\xec\x82\xac\xea\xb3...        240
# 25068  b'\xec\x98\x9b\xeb\x82\xa0\xea\xbc\xac\xeb\xa6...        240
# 25069  b'\xec\x98\x9b\xeb\x82\xa0\xec\x82\xac\xea\xb3...        240
#
#        열량 (kcal)  탄수화물 (g)  단백질 (g)  지방 (g)  당류 (g)  나트륨 (mg) 콜레스테롤 (mg)  \
# 0          11.00      2.70     0.00    0.00    2.20      0.00       b'0'
# 1          84.79     10.12     1.19    4.46    0.45     80.33    b'0.82'
# 2         150.00     22.00     2.00    6.00    1.00    150.00       b'0'
# 3         150.00     22.00     2.00    6.00    0.26    150.00       b'0'
# 4         155.45     18.55     1.64    8.18    1.09    147.27       b'0'
# 5          84.79     10.12     0.89    4.46    0.33     80.33       b'0'
# 6         152.73     18.55     2.18    7.64    1.09    169.09       b'0'
# 7          83.31     10.12     1.19    4.17    0.33     92.23       b'0'
# 8         513.60     72.84    10.32   17.88    0.00   2378.40       b'0'
# 9         616.32     87.41    12.38   21.46    4.80   2854.08       None
# 25065     114.62      2.59    15.38    4.78    0.00   1497.60   b'34.62'
# 25066      47.76      1.08     6.41    1.99    0.00    624.00   b'14.42'
# 25067      37.68      0.02     7.01    1.06    0.00    448.80    b'5.06'
# 25068      57.12      0.14     8.90    2.33    0.00    410.40   b'15.58'
# 25069      90.43      0.06    16.82    2.53    0.00   1077.12   b'12.15'
#
#        포화지방산 (g)  트랜스지방산 (g)
# 0           0.00        0.00
# 1           1.40        0.00
# 2           1.80        0.00
# 3           1.80        0.00
# 4           2.29        0.15
# 5           1.25        0.08
# 6           2.07        0.15
# 7           1.13        0.08
# 8           0.00        0.00
# 9            NaN         NaN
# 10          0.00        0.00
# 11           NaN         NaN
# 12          0.00        0.00
# 13           NaN         NaN
# 14          0.00        0.00
# 15           NaN         NaN
# 16          0.00        0.00
# 17           NaN         NaN
# 18          0.00        0.00
# 19           NaN         NaN
# 20          0.00        0.00
# 21           NaN         NaN
# 22          0.00        0.00
# 23           NaN         NaN
# 24          0.00        0.00
# 25           NaN         NaN
# 26          0.60        0.00
# 27          2.09        0.00
# 28          1.46        0.00
# 29          2.70        0.00
# ...          ...         ...
# 25040      10.50        0.90
# 25041       7.30        0.40
# 25042       1.00        0.00
# 25043       3.20        0.00
# 25044       3.20        0.00
# 25045       2.22        0.00
# 25046       1.43        0.00
# 25047       2.00        0.00
# 25048       3.03        0.00
# 25049       1.00        0.59
# 25050       3.03        1.79
# 25051       1.00        0.00
# 25052       0.33        0.00
# 25053       0.60        0.00
# 25054       2.01        0.00
# 25055       2.01        0.00
# 25056       2.10        0.00
# 25057       0.63        0.00
# 25058       1.11        0.00
# 25059       0.60        0.00
# 25060       1.38        0.06
# 25061       1.54        0.05
# 25062       0.58        0.02
# 25063       3.69        0.12
# 25064       2.30        0.23
# 25065       2.19        0.35
# 25066       0.91        0.14
# 25067       0.62        0.05
# 25068       0.96        0.10
# 25069       1.50        0.12
#
# [25070 rows x 13 columns]

# %%
db.close()

# %%
df['식품군'][1]
# Out:
# b'\xea\xb3\xbc\xec\x9e\x90\xeb\xa5\x98'

# %%
change_list_gun = []
change_list_name = [] 

for i in range(len(df['식품군'])):
    tmp  = df['식품군'][i].decode('utf-8')
    tmp2 = df['식품이름'][i].decode('utf-8')
    change_list_gun.append(tmp)
    change_list_name.append(tmp2)
    
df['식품군']  = change_list
df['식품이름'] = change_list_name

# %%
df.head(5)
# Out:
#    번호  식품군            식품이름  1회제공량 (g)  열량 (kcal)  탄수화물 (g)  단백질 (g)  지방 (g)  \
# 0   1  과자류  츄파춥스 엑스엑스엘 트리오         10      11.00      2.70     0.00    0.00
# 1   2  과자류            오징어집         30      84.79     10.12     1.19    4.46
# 2   3  과자류             감자깡         30     150.00     22.00     2.00    6.00
# 3   4  과자류             감자깡         30     150.00     22.00     2.00    6.00
# 4   5  과자류      후라이드치킨 닭다리         30     155.45     18.55     1.64    8.18
#
#    당류 (g)  나트륨 (mg) 콜레스테롤 (mg)  포화지방산 (g)  트랜스지방산 (g)
# 0    2.20      0.00       b'0'       0.00        0.00
# 1    0.45     80.33    b'0.82'       1.40        0.00
# 2    1.00    150.00       b'0'       1.80        0.00
# 3    0.26    150.00       b'0'       1.80        0.00
# 4    1.09    147.27       b'0'       2.29        0.15
